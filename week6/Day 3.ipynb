# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#import linear regression model
from sklearn.linear_model import LinearRegression
sns.set(color_codes=True)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.formula.api as smf
from sklearn.linear_model import LogisticRegression

# %%
A=pd.read_csv('Advertising-1.csv', index_col=0)

# %%
new_col=A['TV']*A['Radio']

y= A[['Sales']]

x2= A[['TV', 'Radio']]
x3= A[['TV', 'Radio', 'Newspaper']]

# %% [markdown]
# ## Performance Metric of Regression Model

# %%
A["TvRadio"]= new_col

# %%
x1=A[['TV', 'Radio', 'TvRadio']]

# %%
m1= LinearRegression()
m2= LinearRegression()
m3= LinearRegression()

# %% [markdown]
# ### Model 1 : tv radio, tvRadio

# %%
m1.fit(x1,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
m1.intercept_, m1.coef_[0]
# Out:
# (array([6.7502202]), array([0.01910107, 0.02886034, 0.00108649]))

# %%
m1.score(x1,y)
# Out:
# 0.9677905498482523

# %%
y1predict= m1.predict(x1)

# %%
plt.scatter(y1predict,y)

# %% [markdown]
# Tv radio

# %%
m2.fit(x2,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y2predict= m2.predict(x2)

# %%
plt.scatter(y2predict,y)

# %% [markdown]
# tv radio newspaper

# %%
m3.fit(x3,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y3predict= m3.predict(x3)

# %%
plt.scatter(y3predict,y)

# %%
m= (y3predict-np.mean(y3predict))*(y-np.mean(y))/(len(y)-1)

# %%
n=(np.sum(y3predict-np.mean(y3predict)**2)/len(y)-1)

# %%
p= np.sqrt(n)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Prediction for Model3

# %%
m0=smf.ols("Sales~TV+Radio+Newspaper", A).fit()

# %%
m0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):           1.58e-96
# Time:                        10:26:48   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
np.corrcoef(y1predict,y,rowvar=False)
# Out:
# array([[1.        , 0.98376346],
#        [0.98376346, 1.        ]])

# %% [markdown]
# Prediction for model2

# %%
m4=smf.ols("Sales~TV+Radio", A).fit()
m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):           4.83e-98
# Time:                        10:31:39   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# ...

# %%
#Summary for model 1

# %%
m5=smf.ols("Sales~TV+Radio+TvRadio", A).fit()
m5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     1963.
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):          6.68e-146
# Time:                        10:33:09   Log-Likelihood:                -270.14
# No. Observations:                 200   AIC:                             548.3
# Df Residuals:                     196   BIC:                             561.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7502      0.248     27.233      0.000       6.261       7.239
# ...

# %% [markdown]
# ## Logistic Regression
