# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\Desktop\\great learning\\Day1'

# %%
cd C:\Users\ASUS\Desktop\great learning\data sets
# Out:
# C:\Users\ASUS\Desktop\great learning\data sets

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\Desktop\\great learning\\data sets'

# %%
pd.read_csv("gdp_improvement_rate.csv")
# Out:
#                                  country   growth_rate
# 0                             Bangladesh        13.438
# 1                               Ethiopia         8.464
# 2                                  China         6.800
# 3              Ivory Coast Cote d'Ivoire         7.632
# 4                                  Nepal         7.499
# 5                                   Iraq         7.234
# 6                                  India         7.200
# 7                                 Canada         7.146
# 8                       DjiboutiDjibouti         7.000
# 9                               Cambodia         6.947
# 10                        LaosLao P.D.R.         6.907
# 11                               Senegal         6.801
# 12                                 Macau         6.765
# 13                                Guinea         6.660
# 14                           Philippines         6.600
# 15                          Turkmenistan         6.505
# ...
